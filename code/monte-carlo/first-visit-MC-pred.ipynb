# %%
import numpy as np
import sys

if "../" not in sys.path:
  sys.path.append("../") 
from env.blackjack import BlackjackEnv

# %%
env = BlackjackEnv()

# Initial value function
V = {}
Returns = {}
Counts = {}

def get_action_policy(state):
    
    score, dealer_score, usable_ace = state
    return 0 if score >= 20 else 1

# %%
def gen_episode():
    episode = []
    current_state = env.reset()
    
    while(True):
        action = get_action_policy(current_state) # 0 or 1
        next_state, reward, done, _ = env.step(action)
        episode.append((current_state, action, reward))
        if done:
            break
        current_state = next_state
        
    return episode

# %%
n_episodes = 1000

for k in range(n_episodes):
    
    episode = gen_episode()
    
    states_in_episode = [sar[0] for sar in episode]    
    for i,s in enumerate(states_in_episode):
        
        if i>=1 and s not in states_in_episode[:i-1]:
            
            G = sum([sar[2] for i,sar in enumerate(episode[i:])])
            
            if s in Returns.keys():
                Returns[s] += G
            else:
                Returns[s] = G
                
            if s in Counts.keys():
                Counts[s] += 1.0
            else:
                Counts[s] = 1.0
            
            V[s] = Returns[s]/Counts[s]
V
# Out:
# {(18, 3, False): -0.42157229012115066,
#  (21, 6, False): 0.9,
#  (13, 10, False): -0.9117647058823529,
#  (18, 10, False): -0.8933333333333333,
#  (18, 7, False): -0.76,
#  (21, 5, True): 0.7857142857142857,
#  (21, 10, True): 0.9302325581395349,
#  (14, 10, False): -0.9545454545454546,
#  (17, 10, True): 0.0,
#  (19, 1, True): -1.0,
#  (18, 1, False): -0.8333333333333334,
#  (20, 1, False): 0.15384615384615385,
#  (12, 1, False): -0.7142857142857143,
#  (21, 1, False): 0.9333333333333333,
#  (20, 8, False): 0.7857142857142857,
#  (17, 7, False): -1.0,
#  (15, 3, False): -1.0,
#  (19, 10, False): -0.9102564102564102,
#  (14, 4, False): -0.2,
#  (16, 4, False): -1.0,
#  (21, 10, False): 0.8450704225352113,
#  (17, 5, False): -0.8636363636363636,
#  (18, 6, False): -0.8260869565217391,
#  (20, 9, False): 0.7916666666666666,
#  (20, 4, False): 1.0,
#  (15, 1, False): -1.0,
#  (16, 6, False): -0.84,
#  (18, 8, False): -0.8947368421052632,
#  (15, 9, False): -0.8181818181818182,
#  (20, 2, False): 0.6111111111111112,
#  (20, 7, False): 0.6666666666666666,
#  (19, 9, True): -0.5,
#  (19, 9, False): -0.9090909090909091,
#  (15, 8, False): -0.8,
#  (16, 10, False): -0.734375,
#  (19, 3, False): -1.0,
#  (15, 7, False): -1.0,
#  (16, 7, False): -0.84,
#  (21, 8, False): 1.0,
#  (20, 3, False): 0.7428571428571429,
#  (15, 10, False): -0.8888888888888888,
#  (16, 8, False): -0.9047619047619048,
#  (20, 10, False): 0.3609022556390977,
#  (16, 3, False): -0.8823529411764706,
#  (16, 2, False): -1.0,
#  (16, 5, False): -0.7647058823529411,
#  (15, 5, False): -0.9166666666666666,
#  (14, 9, False): -0.8461538461538461,
#  (18, 2, False): -0.625,
#  (20, 6, False): 0.6153846153846154,
#  (17, 1, False): -0.9523809523809523,
#  (17, 10, False): -0.8169014084507042,
#  (19, 5, False): -1.0,
#  (16, 9, False): -0.75,
#  (17, 2, False): -0.8181818181818182,
#  (21, 8, True): 0.8,
#  (14, 3, False): -1.0,
#  (21, 7, False): 0.9473684210526315,
#  (19, 1, False): -0.8823529411764706,
#  (19, 7, False): -0.6842105263157895,
#  (12, 7, False): -1.0,
#  (21, 7, True): 0.8333333333333334,
#  (13, 8, False): -1.0,
#  (14, 6, False): -1.0,
#  (13, 9, False): -0.5555555555555556,
#  (19, 8, False): -0.9310344827586207,
#  (18, 4, False): -0.7333333333333333,
#  (15, 2, False): -1.0,
#  (21, 4, False): 0.8421052631578947,
#  (21, 9, True): 0.8888888888888888,
#  (17, 9, False): -1.0,
#  (17, 3, False): -0.875,
#  (17, 5, True): -0.3333333333333333,
#  (20, 10, True): 0.15789473684210525,
#  (21, 9, False): 1.0,
#  (21, 2, False): 0.9285714285714286,
#  (17, 4, False): -0.8571428571428571,
#  (19, 4, False): -0.7391304347826086,
#  (18, 9, False): -0.8,
#  (13, 7, False): -1.0,
#  (19, 6, False): -1.0,
#  (14, 8, False): -1.0,
#  (21, 3, False): 0.8333333333333334,
#  (15, 8, True): -1.0,
#  (12, 8, False): -0.8181818181818182,
#  (12, 5, False): -1.0,
#  (21, 1, True): 0.7333333333333333,
#  (13, 2, False): -1.0,
#  (19, 2, False): -1.0,
#  (12, 10, False): -0.8421052631578947,
#  (14, 7, False): -0.8333333333333334,
#  (14, 1, False): -1.0,
#  (17, 8, False): -1.0,
#  (12, 3, False): -0.3333333333333333,
#  (13, 3, False): -1.0,
#  (17, 6, False): -0.7857142857142857,
#  (16, 1, False): -0.9375,
#  (13, 5, False): -0.5,
#  (12, 9, False): -0.7777777777777778,
#  (20, 9, True): 1.0,
#  (15, 6, False): -1.0,
#  (13, 6, False): -0.8181818181818182,
#  (21, 5, False): 0.8571428571428571,
#  (20, 3, True): 0.75,
#  (18, 5, False): -0.6666666666666666,
#  (12, 4, False): -1.0,
#  (20, 2, True): 0.0,
#  (20, 5, False): 0.5217391304347826,
#  (21, 4, True): 0.8,
#  (12, 6, False): -1.0,
#  (20, 4, True): 1.0,
#  (18, 2, True): 0.5,
#  (15, 2, True): -1.0,
#  (21, 3, True): 1.0,
#  (14, 2, False): -1.0,
#  (13, 1, False): -0.6666666666666666,
#  (20, 8, True): 1.0,
#  (21, 2, True): 1.0,
#  (14, 10, True): 1.0,
#  (14, 5, False): -0.75,
#  (20, 7, True): 0.0,
#  (13, 4, False): -0.5555555555555556,
#  (12, 2, False): -0.8181818181818182,
#  (21, 6, True): 0.75,
#  (16, 9, True): 0.0,
#  (19, 10, True): -0.5,
#  (20, 1, True): -1.0,
#  (20, 6, True): 0.75,
#  (15, 4, False): -1.0,
#  (15, 3, True): 1.0,
#  (16, 3, True): 1.0,
#  (17, 4, True): -1.0,
#  (17, 1, True): -1.0,
#  (18, 10, True): -0.6666666666666666,
#  (19, 3, True): 1.0,
#  (20, 5, True): -1.0,
#  (18, 9, True): 1.0,
#  (19, 7, True): 0.0,
#  (13, 4, True): -1.0,
#  (17, 6, True): -1.0,
#  (14, 5, True): 1.0,
#  (19, 5, True): 0.0,
#  (18, 5, True): -1.0,
#  (17, 8, True): 1.0,
#  (19, 8, True): -1.0,
#  (14, 9, True): -1.0}
