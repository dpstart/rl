# %%
import numpy as np
import sys

if "../" not in sys.path:
  sys.path.append("../") 
from env.blackjack import BlackjackEnv

# %%
env = BlackjackEnv()

# Initial value function
V = {}
Returns = {}
Counts = {}

def get_action_policy(state):
    
    score, dealer_score, usable_ace = state
    return 0 if score >= 20 else 1

# %%
def gen_episode():
    episode = []
    current_state = env.reset()
    
    while(True):
        action = get_action_policy(current_state) # 0 or 1
        next_state, reward, done, _ = env.step(action)
        episode.append((current_state, action, reward))
        if done:
            break
        current_state = next_state
        
    return episode

# %%
n_episodes = 1000

for k in range(n_episodes):
    
    episode = gen_episode()
    
    states_in_episode = [sar[0] for sar in episode]    
    for i,s in enumerate(states_in_episode):
        
        G = sum([sar[2] for i,sar in enumerate(episode[i:])])

        if s in Returns.keys():
            Returns[s] += G
        else:
            Returns[s] = G

        if s in Counts.keys():
            Counts[s] += 1.0
        else:
            Counts[s] = 1.0

        V[s] = Returns[s]/Counts[s]
V
# Out:
# {(13, 5, False): -0.8,
#  (16, 5, False): -0.75,
#  (18, 10, False): -0.7222222222222222,
#  (14, 9, False): -0.7647058823529411,
#  (21, 6, True): 1.0,
#  (18, 10, True): -0.75,
#  (18, 8, True): -0.6,
#  (18, 8, False): -1.0,
#  (19, 6, True): -1.0,
#  (16, 6, False): -0.6923076923076923,
#  (18, 3, False): -0.8,
#  (16, 10, False): -0.7727272727272727,
#  (17, 3, True): 1.0,
#  (13, 3, False): -0.3076923076923077,
#  (21, 3, False): 0.9230769230769231,
#  (16, 2, False): -0.23076923076923078,
#  (15, 4, False): -0.5,
#  (14, 2, False): -0.16666666666666666,
#  (21, 2, False): 0.8181818181818182,
#  (16, 9, False): -0.5,
#  (15, 10, False): -0.48717948717948717,
#  (16, 1, True): -1.0,
#  (16, 1, False): -1.0,
#  (14, 4, False): -0.4666666666666667,
#  (19, 3, False): -0.6,
#  (12, 10, False): -0.5806451612903226,
#  (21, 10, False): 0.9230769230769231,
#  (21, 4, False): 1.0,
#  (19, 8, False): -0.6153846153846154,
#  (17, 3, False): -0.38461538461538464,
#  (21, 7, True): 0.8888888888888888,
#  (15, 9, True): 0.6666666666666666,
#  (12, 9, False): -0.3333333333333333,
#  (19, 9, False): -0.8,
#  (20, 9, False): 0.7647058823529411,
#  (21, 8, False): 0.8571428571428571,
#  (13, 10, False): -0.6944444444444444,
#  (19, 5, False): -0.9285714285714286,
#  (20, 10, False): 0.4827586206896552,
#  (20, 7, False): 0.8235294117647058,
#  (15, 4, True): -1.0,
#  (16, 4, False): -0.75,
#  (14, 10, False): -0.40540540540540543,
#  (13, 8, False): -0.8181818181818182,
#  (12, 8, False): -0.7272727272727273,
#  (15, 8, False): -0.8461538461538461,
#  (17, 10, False): -0.8125,
#  (15, 2, False): -0.8,
#  (21, 5, False): 0.6363636363636364,
#  (17, 9, False): -1.0,
#  (18, 2, False): -0.8333333333333334,
#  (19, 2, False): -1.0,
#  (20, 4, False): 0.5555555555555556,
#  (18, 1, False): -0.7777777777777778,
#  (13, 6, False): -0.35294117647058826,
#  (13, 4, False): -0.3333333333333333,
#  (19, 4, False): -0.3333333333333333,
#  (13, 2, False): -1.0,
#  (12, 5, False): -0.38461538461538464,
#  (20, 5, False): 0.4666666666666667,
#  (14, 6, False): -0.25,
#  (13, 7, False): -0.5555555555555556,
#  (12, 7, True): 1.0,
#  (15, 7, True): 1.0,
#  (17, 6, False): -0.3333333333333333,
#  (20, 2, False): 0.75,
#  (15, 9, False): -0.3333333333333333,
#  (21, 7, False): 1.0,
#  (19, 10, True): -0.5714285714285714,
#  (20, 10, True): 1.0,
#  (12, 4, False): -0.75,
#  (18, 5, False): -0.8181818181818182,
#  (19, 4, True): 1.0,
#  (20, 4, True): 1.0,
#  (15, 6, False): -0.3333333333333333,
#  (20, 6, False): 0.7727272727272727,
#  (21, 6, False): 0.8888888888888888,
#  (17, 4, False): -0.8,
#  (13, 1, False): -0.7777777777777778,
#  (21, 1, True): 0.5,
#  (16, 8, False): -0.9333333333333333,
#  (12, 3, False): -0.7777777777777778,
#  (20, 8, False): 0.5,
#  (18, 9, False): -0.7777777777777778,
#  (18, 6, False): -1.0,
#  (16, 3, False): -0.4,
#  (18, 4, False): -0.5555555555555556,
#  (15, 10, True): -0.6666666666666666,
#  (21, 10, True): 0.9090909090909091,
#  (17, 7, False): -0.7777777777777778,
#  (19, 7, False): -0.6666666666666666,
#  (12, 1, False): -0.9333333333333333,
#  (20, 1, True): -0.3333333333333333,
#  (14, 7, True): 0.0,
#  (18, 7, True): -1.0,
#  (14, 7, False): -0.6153846153846154,
#  (16, 7, False): -0.7,
#  (18, 7, False): -0.7777777777777778,
#  (21, 8, True): 0.8571428571428571,
#  (16, 10, True): -0.2,
#  (17, 10, True): -1.0,
#  (19, 6, False): -0.7272727272727273,
#  (14, 8, False): -0.6666666666666666,
#  (19, 10, False): -0.8636363636363636,
#  (19, 1, False): -0.6666666666666666,
#  (15, 1, False): -0.5555555555555556,
#  (21, 9, True): 1.0,
#  (14, 5, False): -0.2222222222222222,
#  (15, 5, False): -0.5555555555555556,
#  (16, 5, True): -1.0,
#  (17, 8, False): -0.42857142857142855,
#  (21, 3, True): 1.0,
#  (17, 4, True): -1.0,
#  (20, 1, False): 0.21428571428571427,
#  (21, 2, True): 0.875,
#  (12, 7, False): -0.6666666666666666,
#  (14, 4, True): 1.0,
#  (18, 4, True): 1.0,
#  (21, 4, True): 1.0,
#  (14, 1, False): -0.6666666666666666,
#  (21, 1, False): 0.6666666666666666,
#  (15, 3, False): -0.5,
#  (20, 5, True): 0.3333333333333333,
#  (13, 10, True): -1.0,
#  (14, 10, True): -0.3333333333333333,
#  (21, 5, True): 1.0,
#  (14, 3, False): -0.4,
#  (15, 3, True): 1.0,
#  (12, 2, False): -0.8,
#  (14, 1, True): -1.0,
#  (17, 2, True): -1.0,
#  (17, 2, False): -0.5714285714285714,
#  (17, 1, False): -1.0,
#  (20, 3, True): 1.0,
#  (20, 3, False): 0.7333333333333333,
#  (19, 9, True): 1.0,
#  (20, 9, True): 0.25,
#  (12, 6, False): -0.7777777777777778,
#  (19, 7, True): 0.3333333333333333,
#  (15, 6, True): -1.0,
#  (12, 9, True): -1.0,
#  (18, 9, True): 0.0,
#  (17, 5, False): 0.0,
#  (13, 9, False): -1.0,
#  (15, 7, False): -0.5555555555555556,
#  (17, 1, True): -1.0,
#  (13, 1, True): -1.0,
#  (16, 2, True): -0.5,
#  (20, 2, True): -0.5,
#  (12, 10, True): 0.0,
#  (21, 9, False): 1.0,
#  (15, 8, True): 1.0,
#  (19, 5, True): 0.3333333333333333,
#  (12, 5, True): -1.0,
#  (15, 5, True): 0.0,
#  (18, 6, True): -1.0,
#  (19, 8, True): -1.0,
#  (17, 7, True): -0.5,
#  (15, 1, True): 0.5,
#  (17, 9, True): -1.0,
#  (18, 5, True): -1.0,
#  (20, 6, True): 1.0,
#  (12, 2, True): -1.0,
#  (14, 9, True): -1.0,
#  (16, 9, True): -1.0,
#  (14, 6, True): -1.0,
#  (14, 5, True): -1.0,
#  (14, 2, True): -1.0,
#  (16, 7, True): -1.0,
#  (19, 2, True): -1.0}
