# %%
import numpy as np
import sys

if "../" not in sys.path:
  sys.path.append("../") 
from env.blackjack import BlackjackEnv

# %%
env = BlackjackEnv()

# Initial value function
V = {}
Returns = {}
Counts = {}

def get_action_policy(state):
    
    score, dealer_score, usable_ace = state
    return 0 if score >= 20 else 1

# %%
def gen_episode():
    episode = []
    current_state = env.reset()
    
    while(True):
        action = get_action_policy(current_state) # 0 or 1
        next_state, reward, done, _ = env.step(action)
        episode.append((current_state, action, reward))
        if done:
            break
        current_state = next_state
        
    return episode

# %%
n_episodes = 1000

for k in range(n_episodes):
    
    episode = gen_episode()
    
    states_in_episode = [sar[0] for sar in episode]    
    for i,s in enumerate(states_in_episode):
        
        G = sum([sar[2] for i,sar in enumerate(episode[i:])])

        if s in Returns.keys():
            Returns[s] += G
        else:
            Returns[s] = G

        if s in Counts.keys():
            Counts[s] += 1.0
        else:
            Counts[s] = 1.0

        V[s] = Returns[s]/Counts[s]
V
# Out:
# {(18, 3, False): -0.42165074961318894,
#  (21, 6, False): 0.9032258064516129,
#  (13, 10, False): -0.8780487804878049,
#  (18, 10, False): -0.7843137254901961,
#  (18, 7, False): -0.75,
#  (21, 5, True): 0.7857142857142857,
#  (21, 10, True): 0.9148936170212766,
#  (14, 10, False): -0.7358490566037735,
#  (17, 10, True): 0.2857142857142857,
#  (19, 1, True): -1.0,
#  (18, 1, False): -0.7142857142857143,
#  (20, 1, False): 0.22580645161290322,
#  (12, 1, False): -0.7142857142857143,
#  (21, 1, False): 0.9047619047619048,
#  (20, 8, False): 0.7368421052631579,
#  (17, 7, False): -0.9130434782608695,
#  (15, 3, False): -0.8461538461538461,
#  (19, 10, False): -0.826530612244898,
#  (14, 4, False): -0.14285714285714285,
#  (16, 4, False): -1.0,
#  (21, 10, False): 0.875,
#  (17, 5, False): -0.88,
#  (18, 6, False): -0.8709677419354839,
#  (20, 9, False): 0.7666666666666667,
#  (20, 4, False): 0.972972972972973,
#  (15, 1, False): -0.875,
#  (16, 6, False): -0.7931034482758621,
#  (18, 8, False): -0.8181818181818182,
#  (15, 9, False): -0.6923076923076923,
#  (20, 2, False): 0.55,
#  (20, 7, False): 0.7352941176470589,
#  (19, 9, True): -0.6666666666666666,
#  (19, 9, False): -0.92,
#  (15, 8, False): -0.7368421052631579,
#  (16, 10, False): -0.7625,
#  (19, 3, False): -0.9375,
#  (15, 7, False): -0.8666666666666667,
#  (16, 7, False): -0.7857142857142857,
#  (21, 8, False): 1.0,
#  (20, 3, False): 0.723404255319149,
#  (15, 10, False): -0.875,
#  (16, 8, False): -0.7777777777777778,
#  (20, 10, False): 0.375,
#  (16, 3, False): -0.9047619047619048,
#  (16, 2, False): -0.9090909090909091,
#  (16, 5, False): -0.7647058823529411,
#  (15, 5, False): -0.9285714285714286,
#  (14, 9, False): -0.875,
#  (18, 2, False): -0.6470588235294118,
#  (20, 6, False): 0.6129032258064516,
#  (17, 1, False): -0.8846153846153846,
#  (17, 10, False): -0.8505747126436781,
#  (19, 5, False): -0.9285714285714286,
#  (16, 9, False): -0.7647058823529411,
#  (17, 2, False): -0.8518518518518519,
#  (21, 8, True): 0.8333333333333334,
#  (14, 3, False): -1.0,
#  (21, 7, False): 0.9583333333333334,
#  (19, 1, False): -0.8888888888888888,
#  (19, 7, False): -0.7777777777777778,
#  (12, 7, False): -1.0,
#  (21, 7, True): 0.875,
#  (13, 8, False): -1.0,
#  (14, 6, False): -1.0,
#  (13, 9, False): -0.6363636363636364,
#  (19, 8, False): -0.8823529411764706,
#  (18, 4, False): -0.7777777777777778,
#  (15, 2, False): -1.0,
#  (21, 4, False): 0.8181818181818182,
#  (21, 9, True): 0.8888888888888888,
#  (17, 9, False): -1.0,
#  (17, 3, False): -0.9166666666666666,
#  (17, 5, True): -0.3333333333333333,
#  (20, 10, True): 0.22727272727272727,
#  (21, 9, False): 1.0,
#  (21, 2, False): 0.8421052631578947,
#  (17, 4, False): -0.8095238095238095,
#  (19, 4, False): -0.7586206896551724,
#  (18, 9, False): -0.7727272727272727,
#  (13, 7, False): -1.0,
#  (19, 6, False): -1.0,
#  (14, 8, False): -1.0,
#  (21, 3, False): 0.8235294117647058,
#  (15, 8, True): -1.0,
#  (12, 8, False): -0.8181818181818182,
#  (12, 5, False): -1.0,
#  (21, 1, True): 0.6875,
#  (13, 2, False): -1.0,
#  (19, 2, False): -0.92,
#  (12, 10, False): -0.7307692307692307,
#  (14, 7, False): -0.8571428571428571,
#  (14, 1, False): -1.0,
#  (17, 8, False): -0.8823529411764706,
#  (12, 3, False): -0.3333333333333333,
#  (13, 3, False): -0.6363636363636364,
#  (17, 6, False): -0.7058823529411765,
#  (16, 1, False): -0.85,
#  (13, 5, False): -0.6,
#  (12, 9, False): -0.7777777777777778,
#  (20, 9, True): 1.0,
#  (15, 6, False): -1.0,
#  (13, 6, False): -0.8461538461538461,
#  (21, 5, False): 0.8095238095238095,
#  (20, 3, True): 0.75,
#  (18, 5, False): -0.625,
#  (12, 4, False): -0.7142857142857143,
#  (20, 2, True): 0.5,
#  (20, 5, False): 0.5714285714285714,
#  (21, 4, True): 0.8,
#  (12, 6, False): -1.0,
#  (20, 4, True): 1.0,
#  (18, 2, True): 0.6666666666666666,
#  (15, 2, True): -1.0,
#  (21, 3, True): 1.0,
#  (14, 2, False): -1.0,
#  (13, 1, False): -0.6923076923076923,
#  (20, 8, True): 1.0,
#  (21, 2, True): 1.0,
#  (14, 10, True): 1.0,
#  (14, 5, False): -0.6,
#  (20, 7, True): 0.0,
#  (13, 4, False): -0.5555555555555556,
#  (12, 2, False): -0.8181818181818182,
#  (21, 6, True): 0.75,
#  (16, 9, True): -0.3333333333333333,
#  (19, 10, True): -0.4,
#  (20, 1, True): -1.0,
#  (20, 6, True): 0.8333333333333334,
#  (15, 4, False): -1.0,
#  (15, 3, True): 1.0,
#  (16, 3, True): -0.3333333333333333,
#  (17, 4, True): -1.0,
#  (17, 1, True): -1.0,
#  (18, 10, True): -0.75,
#  (19, 3, True): 0.0,
#  (20, 5, True): -1.0,
#  (18, 9, True): 1.0,
#  (19, 7, True): -0.3333333333333333,
#  (13, 4, True): -1.0,
#  (17, 6, True): -1.0,
#  (14, 5, True): 1.0,
#  (19, 5, True): -0.5,
#  (18, 5, True): -1.0,
#  (17, 8, True): 1.0,
#  (19, 8, True): -1.0,
#  (14, 9, True): -1.0,
#  (16, 7, True): -1.0,
#  (16, 2, True): 0.0,
#  (14, 8, True): -1.0,
#  (19, 4, True): -1.0,
#  (16, 10, True): 1.0,
#  (18, 6, True): -1.0,
#  (15, 1, True): 1.0,
#  (17, 2, True): 1.0,
#  (19, 2, True): -1.0}
